# %%
from pandas import Series, DataFrame

import numpy as np

import string
import re
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams

# %matplotlib inline
from collections import Counter

# %%
import keras
# Out:
# Using TensorFlow backend.
# C:\Users\orlan\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\orlan\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\orlan\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from csv import reader
from datetime import datetime

# %%
import pandas as pd
import json
import sys
import warnings

# %%
import sklearn
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.linear_model import LinearRegression

# %%
df = ("C:\\Users\\orlan\Median_Household_Income_by_State_by_Race.csv")

# %%
data1 = pd.read_csv(df)

# %%
print (data1)
# Out:
#    State   White  African American  American Indian   Asian  Hispanic
# 0     AL   55265             32188            48188   62639     55511
# 1     AK   84799             58209            49834   69685     63478
# 2     AZ   58435             45310            35251   74430     59806
# 3     AR   49581             30758            37801   65919     35947
# 4     CA   74276             49334            53019   91623     72432
# 5     CO   71221             49634            46082   73189     66528
# 6     CT   82950             47856            41094   93665     57214
# 7     DE   70154             48297            45227   96657     54239
# 8     DC  132040             43564            42788  103898    120500
# 9     FL   56008             39586            45307   68777     52087
# 10    GA   63543             42085            38167   77008     39182
# 11    HI   77486             70100            47298   83089     62348
# ...

# %%
data1.describe()
# Out:
#                White  African American  American Indian          Asian  \
# count      51.000000         51.000000        51.000000      51.000000
# mean    65279.764706      40767.666667     41978.058824   73168.470588
# std     13971.377871       8882.822296      7707.701710   15068.651369
# min     45467.000000      29508.000000     27045.000000   51288.000000
# 25%     56985.000000      33885.500000     37169.500000   62017.000000
# 50%     61342.000000      38655.000000     41664.000000   70759.000000
# 75%     71318.000000      45744.000000     45432.500000   82911.000000
# max    132040.000000      70100.000000     69955.000000  116131.000000
#
#             Hispanic
# count      51.000000
# mean    55589.921569
# std     20113.193127
# min     26287.000000
# 25%     42070.000000
# 50%     52087.000000
# 75%     61333.000000
# max    137572.000000

# %%
data1.min()
# Out:
# State                  AK
# White               45467
# African American    29508
# American Indian     27045
# Asian               51288
# Hispanic            26287
# dtype: object

# %%
data1.max()
# Out:
# State                   WY
# White               132040
# African American     70100
# American Indian      69955
# Asian               116131
# Hispanic            137572
# dtype: object

# %%
import scipy
import math

# %%
data1.plot(kind='scatter', x='State', y='White', c=['blue'])

# %%
data1.plot(kind='scatter', x='State', y='Hispanic')

# %%
data1.plot(kind='scatter', x='State', y='American Indian')

# %%
data1.plot(kind='scatter', x='State', y='Asian')

# %%
data1.plot(kind='scatter', x='State', y='African American')

# %%
data1.plot(kind='bar', x='State', y='African American')

# %%
data1.plot(kind='bar', x='State', y='White')

# %%
data1.plot(kind='bar', x='State', y='American Indian')

# %%
data1.plot(kind='bar', x='State', y='Asian')

# %%
data1.plot(kind='bar', x='State', y='Hispanic')

# %%
import scipy
import math

# %%
linreg = LinearRegression()

# %%
White = np.array([55265,84799,58435,49581,74276,71221,82950,70154,132040,56008,63543,77486,53738,69194,57269,60123,59641,50267,58632,56030,90964,81977,59077,71415,54244,56701,53813,61342,61412,74468,85423,50947,73584,58171,66213,58885,54612,60183,63110,67362,58825,59465,54085,62679,70199,60577,76860,71466,45467,61974,63116])
African_American = np.array([32188,58209,45310,30758,49334,49634,47856,48297,43564,39586,42085,70100,39970,37244,33342,31053,35829,33642,29508,38655,65039,48382,33649,34879,29690,35710,41484,34122,39726,51630,51309,38490,46178,37242,34565,31669,34138,37078,36847,41630,33371,31957,36683,44688,42739,43548,49273,50487,32070,30002,44712])
American_Indian = np.array([48188,49834,35251,37801,53019,46082,41094,45227,42788,45307,38167,47298,40898,47573,41801,36941,43943,33200,41664,32670,69955,42686,42336,36429,33297,40824,32072,37398,41478,47902,53507,33552,41267,38206,36710,33682,42820,42047,37702,34414,39484,27045,43212,52094,41942,41793,61850,45558,29927,41594,49352])
Asian = np.array([62639,69685,74430,65919,91623,73189,93665,96657,103898,68777,77008,83089,53435,85828,62136,60638,68821,62655,61351,55656,102786,91713,82733,75437,59478,67526,58774,56627,65460,83301,116131,65019,72131,80500,62223,73058,56996,75929,72699,72907,61898,51288,72881,84851,70759,55568,102735,90131,58521,66408,54025])
Hispanic = np.array([55511,63478,59806,35947,72432,66528,57214,54239,120500,52087,39182,62348,39051,53958,50789,42077,51903,34885,56667,70500,89265,79919,58547,72917,26287,48696,36380,42063,57109,49014,48429,47311,47227,48398,48715,47894,40486,60028,51705,41155,35280,38958,26466,53659,64594,54258,79474,65024,60318,38836,137572])

# %%
White = White.reshape(-1, 1)

# %%
linreg.fit(White, African_American)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
African_American_pred = linreg.predict(White)

# %%
American_Indian_pred = linreg.predict(White)

# %%
Asian_pred = linreg.predict(White)

# %%
Hispanic_pred = linreg.predict(White)

# %%
plt.scatter(White,African_American)
plt.plot(White, African_American_pred, color='red')
plt.show()

# %%
print(linreg.coef_)
# Out:
# [0.38258542]

# %%
print(linreg.intercept_)
# Out:
# 15792.580599162182

# %%
plt.scatter(White,American_Indian)
plt.plot(White, American_Indian_pred, color='green')
plt.show()

# %%
plt.scatter(White,Asian)
plt.plot(White, Asian_pred, color='blue')
plt.show()

# %%
plt.scatter(White,Hispanic)
plt.plot(White, Hispanic_pred, color='green')
plt.show()
